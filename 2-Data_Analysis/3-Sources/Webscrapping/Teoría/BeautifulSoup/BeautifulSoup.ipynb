# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Extraeremos datos de la página de libros más vendidos de Book Depository, y para lograr esto, también tendrá que hacer uso de un poco de pandas principalmente.

# %% [markdown]
# **Beautiful Soup** es una librería **Python** que permite extraer información de contenido en formato **HTML o XML**. Para usarla, es necesario especificar un **parser**, que es responsable de transformar un documento HTML o XML en un árbol complejo de objetos Python. Esto permite, por ejemplo, que podamos interactuar con los elementos de una página web como si estuviésemos utilizando las herramientas del desarrollador de un navegador.
#
# A la hora de extraer información de una web, uno de los parsers más utilizado es el parser HTML de **lxml**. Precisamente, será el que utilicemos en este tutorial.

# %% [markdown]
# **Será necesario instalar las siguientes librerías** (si no las tienes ya):
#
#         pip install beautifulsoup4 requests pandas
#
#         pip install lxml

# %%
# !pip install beautifulsoup4
# !pip install requests

# %% [markdown]
# ###  Pasos a seguir en el proceso de 'scraping':
#
# 1. Encuentra la URL que quieres 'escrapear'.
# 2. Inspecciona la página (código fuente).
# 3. Localiza los datos que necesitas obtener.
# 4. Desarrolla tu código en Python.
#     1. Crea tu "sopa"
#     2. Busca los elementos que contienen los datos y extráelos
# 5. Ejecuta tu código y obtén los datos.
# 6. Alamacena los datos en el formato requerido.

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
# from splinter import Browser
import numpy as np

pd.set_option('max_colwidth', 800)

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.thebridge.tech/bootcamps/bootcamp-data-science"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!DOCTYPE html><!-- Last Published: Tue May 16 2023 14:48:27 GMT+0000 (Coordinated Universal Time) --><html data-wf-domain="www.thebridge.tech" data-wf-page="642bcdb704ea37ae91616497" data-wf-site="60780bff57ddc42a6adc1d7e" lang="es"><head><meta charset="utf-8"/><title>Data Science | The Bridge</title><meta content="Eleva tus capacidades con el bootcamp de Data Science m\xc3\xa1s completo: formaci\xc3\xb3n inmersiva y mentorizaci\xc3\xb3n continua. The Bridge, el puente hacia tus sue\xc3\xb1os." name="description"/><meta content="Data Science FT | The Bridge" property="og:title"/><meta content="Eleva tus capacidades con el bootcamp de Data Science m\xc3\xa1s completo: formaci\xc3\xb3n inmersiva y mentorizaci\xc3\xb3n continua. The Bridge, el puente hacia tus sue\xc3\xb1os." property="og:description"/><meta content="https://uploads-ssl.webflow.com/60782404b8e195845053206a/61b356a24ba5746ddec2dd6b_iconowebDS.png" property="og:image"/><meta content="Data Science FT | The Bridge" property="twitter:title"/><meta content="Eleva tus capacidades con el bootcamp de Data Science m\xc3\xa1s completo: formaci\xc3\xb3n inmersiva y mentorizaci\xc3\xb3n continua. The Bridge, el puente hacia tus sue\xc3\xb1os." property="twitter:description"/><meta content="https://uploads-ssl.webflow.com/60782404b8e195845053206a/61b356a24ba5746ddec2dd6b_iconowebDS.png" property="twitter:image"/><meta property="og:type" content="website"/><meta content="summary_large_image" name="twitter:card"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/css/the-bridge-site.webflow.722cf25ef.min.css" rel="stylesheet" type="text/css"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://fonts.gstatic.com" rel="preconnect" crossorigin="anonymous"/><script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script><script type="text/javascript">WebFont.load({  google: {    families: ["Lato:100,100italic,300,300italic,400,400italic,700,700italic,900,900italic","Open Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic","Exo:100,100italic,200,200italic,300,300italic,400,400italic,500,500italic,600,600italic,700,700italic,800,800italic,900,900italic","Montserrat:100,100italic,200,200italic,300,300italic,400,400italic,500,500italic,600,600italic,700,700italic,800,800italic,900,900italic","PT Serif:400,400italic,700,700italic","Mulish:regular,700,800","Mulish:regular,700,800","Roboto:100,100italic,300,300italic,regular,italic,500,500italic,700,700italic,900,900italic"]  }});</script><!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif]--><script type="text/javascript">!function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);</script><link href="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60db6e4686410a6b2b28aa16_logo32x32.png" rel="shortcut icon" type="image/x-icon"/><link href="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60db6e49a998588fa6ae698b_logo256x256.png" rel="apple-touch-icon"/><link href="https://thebridge.tech/bootcamps/bootcamp-data-science" rel="canonical"/><style>.anti-flicker-hide { opacity: 0 !important}</style><script type="text/javascript">(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;h.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;})(window,document.documentElement,\'anti-flicker-hide\',\'dataLayer\',4000,{\'OPT-T6K86CT\':true});</script><script type="text/javascript">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.pus ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, 'html.parser')

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!-- Last Published: Tue May 16 2023 14:48:27 GMT+0000 (Coordinated Universal Time) --><html data-wf-domain="www.thebridge.tech" data-wf-page="642bcdb704ea37ae91616497" data-wf-site="60780bff57ddc42a6adc1d7e" lang="es"><head><meta charset="utf-8"/><title>Data Science | The Bridge</title><meta content="Eleva tus capacidades con el bootcamp de Data Science más completo: formación inmersiva y mentorización continua. The Bridge, el puente hacia tus sueños." name="description"/><meta content="Data Science FT | The Bridge" property="og:title"/><meta content="Eleva tus capacidades con el bootcamp de Data Science más completo: formación inmersiva y mentorización continua. The Bridge, el puente hacia tus sueños." property="og:description"/><meta content="https://uploads-ssl.webflow.com/60782404b8e195845053206a/61b356a24ba5746ddec2dd6b_iconowebDS.png" property="og:image"/><meta content="Data Science FT | The Bridge" property="twitter:title"/><meta content="Eleva tus capacidades con el bootcamp de Data Science más completo: formación inmersiva y mentorización continua. The Bridge, el puente hacia tus sueños." property="twitter:description"/><meta content="https://uploads-ssl.webflow.com/60782404b8e195845053206a/61b356a24ba5746ddec2dd6b_iconowebDS.png" property="twitter:image"/><meta content="website" property="og:type"/><meta content="summary_large_image" name="twitter:card"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/css/the-bridge-site.webflow.722cf25ef.min.css" rel="stylesheet" type="text/css"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="anonymous" href="https://fonts.gstatic.com" rel="preconnect"/><script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script><script type="text/javascript">WebFont.load({  google: {    families: ["Lato:100,100italic,300,300italic,400,400italic,700,700italic,900,900italic","Open Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic","Exo:100,100italic,200,200italic,300,300italic,400,400italic,500,500italic,600,600italic,700,700italic,800,800italic,900,900italic","Montserrat:100,100italic,200,200italic,300,300italic,400,400italic,500,500italic,600,600italic,700,700italic,800,800italic,900,900italic","PT Serif:400,400italic,700,700italic","Mulish:regular,700,800","Mulish:regular,700,800","Roboto:100,100italic,300,300italic,regular,italic,500,500italic,700,700italic,900,900italic"]  }});</script><!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif]--><script type="text/javascript">!function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);</script><link href="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60db6e4686410a6b2b28aa16_logo32x32.png" rel="shortcut icon" type="image/x-icon"/><link href="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60db6e49a998588fa6ae698b_logo256x256.png" rel="apple-touch-icon"/><link href="https://thebridge.tech/bootcamps/bootcamp-data-science" rel="canonical"/><style>.anti-flicker-hide { opacity: 0 !important}</style><script type="text/javascript">(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;})(window,document.documentElement,'anti-flicker-hide','dataLayer',4000,{'OPT-T6K86CT':true});</script><script type="text/javascript">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.agent='plwebflow';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getEle ...
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NXTBFGR');</script>
# <!-- End Google Tag Manager -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-THMB6J5');</script>
# <!-- End Google Tag Manager -->
# <style>
#
# a:hover {
#  transition: all 0.3s linear;
# }
#
# .square-element:after {
#   	content: "";
#     display: inline-flex;
#     position: relative;
#     bottom: 8px;
#     padding: 1.5%;
#     margin-left: 5px;
#     background-color: #e22b22;
#     border-radius: 5px;
# }
#
# .link-header-hover:hover:before {
#   content: "";
#   display: inline-flex;
#   position: relative;
#   bottom: 5px;
#   padding: 4px;
#   margin-right: 5px;
#   background-color: #e22b22;
#   border-radius: 3px;
# }
# .image-white img {
#   filter: brightness(0) invert(1);
# }
# .video-vr > div > iframe {
#   position: absolute;
#   width: 100%;
#   height: 100%;
# }
# @media (max-width: 1560px) {
#   .aside-hidden {
#     display: none;
#   }
# }
# </style>
# <script src="https://consent.cookiefirst.com/sites/thebridge.tech-d6002cb0-069d-4c56-8051-fa8608d17e24/consent.js"></script>
# <link href="https://www.thebridge.tech/bootcamps/bootcamp-data-science" rel="canonical"/></head><body><div class="html-embed-21 w-embed w-iframe"><!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NXTBFGR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --></div><div class="html-embed-18 w-embed w-iframe"><!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-THMB6J5" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --></div><div class="html-embed-12 w-embed w-script"><script src="https://www.googleoptimize.com/optimize.js?id=OPT-T6K86CT"></script></div><div class="navbar-2 w-nav" data-animation="default" data-collapse="medium" data-duration="400" data-easing="ease" data-easing2="ease" role="banner"><header class="header_nav" id="header"><div class="container-nav w-container"><a class="brand-2 w-nav-brand" href="/"><img alt="Logo The Bridge" class="image-2" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/607eeb4b0517b6659206c10f_thebridgelogo.svg"/></a><nav class="nav-menu-2 fixed w-nav-menu" role="navigation"><div class="w-dropdown" data-delay="0" data-hover="true"><div class="drop-menu w-dropdown-toggle"><div class="w-icon-dropdown-toggle"></div><div>Cursos</div></div><nav class="w-dropdown-list"><div class="content-menu"><div class="container-elements"><div class="card-menu"><h3 class="heading-7 header-menu"><a class="link" href="/bootcamp/online">Bootcamps ONLINE</a></h3><div class="header2-menu">Estudia de manera online, con flexibilidad horaria y a tu ritmo. Fórmate en 26 semanas.<br/>‍</div><h3 class="heading-7 header-menu"><a class="link" href="/bootcamp/bootcamps-full-time">Bootcamps Full Time</a></h3><div class="header2-menu">Cambia tu vida en un bootcamp intensivo de 16 semanas<br/>‍</div><h3 class="heading-7 header-menu"><a class="link" href="/bootcamp/bootcamps-part-time">Bootcamps part Time</a></h3><div class="header2-menu">Compatibiliza tus estudios con tu trabajo. Fórmate en 26 semanas<br/>‍</div></div><div><h3 class="heading-7 header-menu">CONOCE NUESTROS BOOTCAMPS:</h3><div class="w-dyn-list"><div class="w-dyn-items" role="list"><div class="w-dyn-item" role="listitem"><a class="link-header link-header-hover" href="/bootcamps/bootcamp-ciberseguridad">Ciberseguridad</a></div><div class="w-dyn-item" role="listitem"><a class="link-header link-header-hover" href="/bootcamps/bootcamp-cloud-devops">Cloud &amp; DevOps</a></div><div class="w-dyn-item" role="listitem"><a aria-current="page" class="link-header link-header-hover w--current" href="/bootcamps/bootcamp-data-science">Data Science</a></div><div class="w-dyn-item" role="listitem"><a class="link-header link-header-hover" href="/bootcamps/bootcamp-fullstack-developer">Desarrollo Web Full Stack</a></div><div class="w-dyn-item" role="listitem"><a class="link-header link-header-hover" href="/bootcamps/bootcamp-marketing-digital">Marketing Digital</a></div><div class="w-dyn-item" role="listitem"><a class="link-header link-header-hover" href="/bootcamps/bootcamp-product-design">UX/UI Product Design</a></div></div></div></div></div><div class="container-elements"><div class="card-menu"><h3 class="heading-7 header-menu">eventos y talleres</h3><a class="link-header" href="https://www.eventbrite.es/o/the-bridge-digital-talent-accelerator-26763007783" target="_blank">Descubre los eventos para introducirte en el mundo digital <span class="text-span-2">&gt;</span></a></div></div></div></nav></div><div class="w-dropdown" data-delay="0" data-hover="true"><div class="drop-menu w-dropdown-toggle"><div class="w-icon-dropdown-toggle"></div><div>Dónde estudiar</div></div><nav class="w-dropdown-list"><div class="content-menu"><div class="container-elements"><div class="card-menu"><h3 class="heading-7 header-menu">campus</h3><div class="header2-menu">Explora todos nuestros campus </div><a class="link-header w-inline-block" href="/campus/bootcamps-online"><div class="text-block-208">Bootcamps Online</div></a><a class="link-header w-inline-block" href="/campus/bootcamps-bilbao"><div class="text-block-208">Bootcamps en Bilbao</div></a><a class="link-header w-inline-block" href="/campus/bootcamps-madrid"><div class="text-block-208">Bootcamps en Madrid</div></a><a class="link-header w-inline-block" href="/campus/bootcamps-valencia"><div class="text-block-208">Bootcamps en Valencia</div></a><a class="link-header w-inline-block" href= ...
# <script charset="utf-8" type="text/javascript" src="//js.hsforms.net/forms/v2-legacy.js"></script>
# <![endif]-->
# <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript"></script>
# <script>
#   hbspt.forms.create({
# 	region: "na1",
# 	portalId: "5965645",
# 	formId: "384fbee0-a031-4220-8169-4fff08ee4255"
# });
# </script></div></div></div><div class="section-int black-background display-none wf-section"><div class="title-line"></div><div class="container-content w-container"><div class="title-mini-text headers-white">Encuentra tu momento</div><h2 class="title-section white">Próximas convocatorias</h2></div><div class="slider-8 w-slider" data-animation="slide" data-autoplay="false" data-autoplay-limit="0" data-delay="4000" data-disable-swipe="false" data-duration="1000" data-easing="ease-in" data-hide-arrows="false" data-infinite="true" data-nav-spacing="3"><div class="w-slider-mask"><div class="w-slide"><div class="container-64 w-container"><div class="title-mini-text headers-white center">FULL TIME</div><div class="text-block-209">Fórmate a jornada completa durante 16 semanas. Jornadas intensivas de 8 horas de lunes a jueves y 4 horas los viernes. Próximas ediciones:</div></div><div class="collection-list-wrapper-33 w-dyn-list"><div class="collection-list-25 w-dyn-items" role="list"><div class="w-dyn-item" role="listitem"><div class="card white_margin convocatorias margin"><div class="text-block-200">Mayo 2023</div><div class="text-block-201 convos">22/05</div><div class="black-pill small sedes"><img alt="Icono Reloj" class="image-137 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63e4d647d89630b5205c_Time%20Circle.svg"/><div class="text-block-202 small convos">Full time</div></div><div class="black-pill large convos formato"><img alt="Icono Localización" class="image-137 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63bdeec8ef0ff6d3600d_Location.svg"/><div class="text-block-202 small convos">Presencial / Remoto</div></div><div class="black-pill sede convo"><img alt="Icono Localización" class="image-141 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63bdeec8ef0ff6d3600d_Location.svg"/><div class="text-block-210 convos small">Valencia, Sevilla y Bilbao</div></div></div></div><div class="w-dyn-item" role="listitem"><div class="card white_margin convocatorias margin"><div class="text-block-200">Junio 2023</div><div class="text-block-201 convos">12/06</div><div class="black-pill small sedes"><img alt="Icono Reloj" class="image-137 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63e4d647d89630b5205c_Time%20Circle.svg"/><div class="text-block-202 small convos">Full time</div></div><div class="black-pill large convos formato"><img alt="Icono Localización" class="image-137 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63bdeec8ef0ff6d3600d_Location.svg"/><div class="text-block-202 small convos">Presencial / Remoto</div></div><div class="black-pill sede convo"><img alt="Icono Localización" class="image-141 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63bdeec8ef0ff6d3600d_Location.svg"/><div class="text-block-210 convos small">Madrid</div></div></div></div><div class="w-dyn-item" role="listitem"><div class="card white_margin convocatorias margin"><div class="text-block-200">Septiembre 2023</div><div class="text-block-201 convos">18/09</div><div class="black-pill small sedes"><img alt="Icono Reloj" class="image-137 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63e4d647d89630b5205c_Time%20Circle.svg"/><div class="text-block-202 small convos">Full time</div></div><div class="black-pill large convos formato"><img alt="Icono Localización" class="image-137 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63bdeec8ef0ff6d3600d_Location.svg"/><div class="text-block-202 small convos">Presencial / Remoto</div></div><div class="black-pill sede convo"><img alt="Icono Localización" class="image-141 convos" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60ab63bdeec8ef0ff6d3600d_Location.svg"/><div  ...
# const urlbootcamp = document.location.pathname
# if (urlbootcamp.includes('fullstack') || urlbootcamp.includes('data-science')) {
# 	document.getElementById('onlineBoton').style.display = 'block'
# } else {
# 	document.getElementById('onlineBoton').style.display = 'none'
# }
#
# </script></div></div><div class="section-int w-clearfix wf-section" id="metodologia"><div class="title-line right" style="background-color:#02cfff"></div><div class="container-content w-container"><div class="title-mini-text">descubre nuestra metodología</div><h2 class="title-section">¿Cómo lo aprenderás?</h2><div class="method"><div class="rich-text-block-9 w-richtext"><h2>Un bootcamp es una experiencia y se caracteriza por ser intensivo e inmersivo.</h2><h4>Full Time: 16 semanas - Part Time : 26 semanas - Online 26 semanas</h4><p>Nuestra metodología te asegura la preparación completa necesaria para desarrollar el trabajo a pleno rendimiento desde el primer día.</p></div><img alt="Cómo aprenderás GIF " class="image-140" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/637505c1ee61c989ceb61812_Como-aprenderas-gif_mb.gif"/><img alt="Como aprenderás GIF" class="image-139" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/637505c2dfa081bada0f592c_Como-aprenderas-gif.gif"/></div></div></div><div class="background-cards secondary-background wf-section" id="tarifas"><div class="w-container"><h2 class="title-section headers-white">Nuestros precios y becas</h2><div class="cards-container cards-right"><div class="cards border display-none"><div class="text-block-37">PRECIO </div><div class="text-block-36"><span><strong class="bold-text-10"> 7.500€<br/></strong></span></div><div class="card-text-block">PLAZAS LIMITADAS<br/> Los precios varían en función de la edición, el campus y las becas o financiación a las que se acoja el alumno.<br/></div><div class="inline-buttons content-right posiition-absolute w-clearfix"><a class="button-style whitebutton w-button" href="/financiacion-becas/financiacion-becas">+ info</a></div></div><div class="cards border big-card"><div class="div-block-298"><div class="div-block-299"><div class="text-block-37 small">PRECIO BOOTCAMP PRESENCIAL:</div><div class="text-block-36"><span><strong class="bold-text-10 small"> 7.500€<br/></strong></span></div></div><div class="div-block-300"><div class="text-block-37 small">PRECIO BOOTCAMP ONLINE:</div><div class="text-block-36"><span><strong class="bold-text-10 small"> 5.500€<br/></strong></span></div></div></div><div class="card-text-block">PLAZAS LIMITADAS<br/> Los precios varían en función de la edición, el campus y las becas o financiación a las que se acoja el alumno.<br/></div><div class="inline-buttons content-right posiition-absolute w-clearfix"><a class="button-style whitebutton w-button" href="/financiacion-becas/financiacion-becas" id="info_becas">+ info</a></div></div><div class="cards border ayudas"><div class="text-block-37">AYUDAS 4TALENT TECH</div><div class="text-block-36"><span><strong class="bold-text-10">5.900€<br/></strong></span></div><div class="card-text-block">PLAZAS LIMITADAS<br/> Para Madrid y Valencia. Consulta condiciones clickando en el botón<br/></div><div class="inline-buttons content-right posiition-absolute w-clearfix"><a class="button-style whitebutton w-button" href="/financiacion-becas/becas-4talent-tech">+ info</a></div></div><div class="cards border display-none w-condition-invisible"><div class="cross-text no-cross">7.000€</div><div class="card-text-block">Consúltanos sobre programas de becas, ayudas, programas de acceso y financiación<br/></div><div class="inline-buttons content-right posiition-absolute w-clearfix"><a class="button-style whitebutton w-button" href="/formularios/formulario-info">+ info</a></div></div><div class="cards border display-none w-condition-invisible"><div class="cross-text no-cross">Paga tus estudios cuando trabajes</div><div class="card-text-block">Si cumples una serie de requisitos y durante el proceso de admisión demuestras capacidad y motivación te damos la opción de cursar tu Bootcamp y pa<br/></div><div class="inline-buttons content-right posiition-absolute"></div></div><div class="cards border display-none w-condition-invisible"><div class=" ...
# <script>
# (function() {
# var fsComponent = new FsLibrary('.fs-dynamic-feed')
#
# fsComponent.slider({
#   sliderComponent: '.fs-slider',
#   resetIx: true
# })
# })();
# </script></body></html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# ![image](img\html-content-web-scraping.png)

# %% [markdown]
# ![image](img\attribute-example-for-web-scraping-1536x386.png)

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>Data Science | The Bridge</title>

# %%
soup.h1
# Out:
# <h1 class="heading headers-white square-element">Data Science</h1>

# %%
soup.h1.get_text()
# Out:
# 'Data Science'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
soup.a['href']
# Out:
# '/'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# También puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
print(soup.a)
print("")
print("Utilizando método .find()")
print(soup.find("a"))
# Out:
# Sin utilizar método .find()
# <a class="brand-2 w-nav-brand" href="/"><img alt="Logo The Bridge" class="image-2" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/607eeb4b0517b6659206c10f_thebridgelogo.svg"/></a>
#
# Utilizando método .find()
# <a class="brand-2 w-nav-brand" href="/"><img alt="Logo The Bridge" class="image-2" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/607eeb4b0517b6659206c10f_thebridgelogo.svg"/></a>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all('a')
# Out:
# [<a class="brand-2 w-nav-brand" href="/"><img alt="Logo The Bridge" class="image-2" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/607eeb4b0517b6659206c10f_thebridgelogo.svg"/></a>,
#  <a class="link" href="/bootcamp/online">Bootcamps ONLINE</a>,
#  <a class="link" href="/bootcamp/bootcamps-full-time">Bootcamps Full Time</a>,
#  <a class="link" href="/bootcamp/bootcamps-part-time">Bootcamps part Time</a>,
#  <a class="link-header link-header-hover" href="/bootcamps/bootcamp-ciberseguridad">Ciberseguridad</a>,
#  <a class="link-header link-header-hover" href="/bootcamps/bootcamp-cloud-devops">Cloud &amp; DevOps</a>,
#  <a aria-current="page" class="link-header link-header-hover w--current" href="/bootcamps/bootcamp-data-science">Data Science</a>,
#  <a class="link-header link-header-hover" href="/bootcamps/bootcamp-fullstack-developer">Desarrollo Web Full Stack</a>,
#  <a class="link-header link-header-hover" href="/bootcamps/bootcamp-marketing-digital">Marketing Digital</a>,
#  <a class="link-header link-header-hover" href="/bootcamps/bootcamp-product-design">UX/UI Product Design</a>,
#  <a class="link-header" href="https://www.eventbrite.es/o/the-bridge-digital-talent-accelerator-26763007783" target="_blank">Descubre los eventos para introducirte en el mundo digital <span class="text-span-2">&gt;</span></a>,
#  <a class="link-header w-inline-block" href="/campus/bootcamps-online"><div class="text-block-208">Bootcamps Online</div></a>,
#  <a class="link-header w-inline-block" href="/campus/bootcamps-bilbao"><div class="text-block-208">Bootcamps en Bilbao</div></a>,
#  <a class="link-header w-inline-block" href="/campus/bootcamps-madrid"><div class="text-block-208">Bootcamps en Madrid</div></a>,
#  <a class="link-header w-inline-block" href="/campus/bootcamps-valencia"><div class="text-block-208">Bootcamps en Valencia</div></a>,
#  <a class="link-header w-inline-block" href="/campus/bootcamps-sevilla"><div class="text-block-208">Bootcamps en Sevilla</div></a>,
#  <a class="link-block-27 w-inline-block" href="http://www.thebridge.tech/campus-bootcamps/online">Descubre las ventajas de estudiar online</a>,
#  <a class="link-header link-header-hover" href="/financiacion-becas/financiacion-becas">Financiación y becas</a>,
#  <a class="link-header link-header-hover" href="/financiacion-becas/income-share-agrement-isa">Estudia ahora y paga después</a>,
#  <a class="link-header link-header-hover" href="/empresas-intituciones/soluciones-empresas">Soluciones para empresas</a>,
#  <a class="link-header link-header-hover" href="/empresas-intituciones/servicios-universidades-instituciones-educativas">Soluciones para instituciones educativas</a>,
#  <a class="link-header link-header-hover" href="/empresas-intituciones/contrata-nuestros-graduados">Contrata nuestros graduados</a>,
#  <a class="link-2" href="/empleabilidad">Empleabilidad</a>,
#  <a class="link-header link-header-hover" href="/sobre-nosotros/quienes-somos">Quiénes somos</a>,
#  <a class="link-header link-header-hover" href="/sobre-nosotros/por-que-the-bridge">Por qué The Bridge</a>,
#  <a class="link-header link-header-hover" href="/sobre-nosotros/equipo-the-bridge">El equipo The Bridge</a>,
#  <a class="link-header link-header-hover" href="/sobre-nosotros/impacto-social">Impacto social</a>,
#  <a class="link-header link-header-hover" href="/sobre-nosotros/career-readiness">Career Readiness</a>,
#  <a class="link-header link-header-hover" href="/blog" target="_blank">Blog</a>,
#  <a class="button-style red-button w-button" href="#info">pide información</a>,
#  <a class="aside-link" href="#resumen">Resumen</a>,
#  <a class="aside-link" href="#curriculum">Curriculum</a>,
#  <a class="aside-link" href="#metodologia">Metodología</a>,
#  <a class="aside-link" href="#para-quien">Para quién</a>,
#  <a class="aside-link" href="#">Equipo docente</a>,
#  <a class="aside-link" href="#">Historias de graduados</a>,
#  <a class="aside-link" href="#tarifas">Precios y becas</a>,
#  <a class="aside-link" href="#proceso-admision">Proceso de admisión</a>,
#  <a class="aside-link" href="#">Próximas ediciones</a>,
#  <a class="aside-link" href="#faqs">FAQs</a>,
#  <a class="button-style red-button w-button" href="/formularios/formulario-admision">solicitar plaza</a>,
#  <a class="button-style whitebutton w-button" href="#info">descargar programa</a>,
#  <a class="cf-home-tab-link-3 w-inline-block w-tab-link w--current" data-w-tab="Tab 1" id="fulltimeBoton"><div>Full Time</div></a>,
#  <a class="cf-home-tab-link-3 w-inline-block w-tab-link" data-w-tab="Tab 2" id="parttimeBoton"><div>Part Time</div></a>,
#  <a class="cf-home-tab-link-3 w-inline-block w-tab-link" data-w-tab="Tab 3" id="onlineBoton"><div>Online</div></a>,
#  <a class="button-style whitebutton w-button" href="/financiacion-becas/financiacion-becas">+ info</a>,
#  <a class="button-style whitebutton w-button" href="/financiacion-becas/financiacion-becas" id="info_becas">+ info</a>,
#  <a class="button-style whitebutton w-button" href="/financiacion-becas/becas-4talent-tech">+ info</a>,
#  <a class="button-style whitebutton w-button" href="/formularios/formulario-info">+ info</a>,
#  <a class="button-style whitebutton w-button" href="#info">+ info</a>,
#  <a class="button-style whitebutton w-button" href="#info">+ info</a>,
#  <a href="tel:+34919017257"><strong>919 01 72 57 </strong></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/miguelangelnievasfuertes/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/albertoromv/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/alberto-becerra-tome-data-science-instructor/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/jlgortega/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/marcusrb/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/gustavomartinvela/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/fernando-carrasco-847a28aa/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/carlos-sevilla-barcel%C3%B3/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/mvalleheath/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/miguelangelnievasfuertes/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/albertoromv/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/alberto-becerra-tome-data-science-instructor/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/jlgortega/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/marcusrb/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/gustavomartinvela/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/fernando-carrasco-847a28aa/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/carlos-sevilla-barcel%C3%B3/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="fs-link w-inline-block" href="https://www.linkedin.com/in/mvalleheath/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a>,
#  <a class="button-style w-button" href="/formularios/formulario-admision">Solicitar Plaza</a>,
#  <a href="tel:+34919017257"><strong>+34 919 01 72 57</strong></a>,
#  <a href="tel:+34919017257"><br/></a>,
#  <a href="tel:+34960663630"><strong>+34 960 663 630</strong></a>,
#  <a href="tel:+34955442930"><strong>+34 955 442 930</strong></a>,
#  <a href="tel:+34944771407"><strong>+34 944 771 407</strong></a>,
#  <a class="link-block-2 w-inline-block" href="https://twitter.com/TheBridge_Tech" target="_blank"><img alt="Logo Twitter" class="rrss-image" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60a258b8b845fee9b1731689_twitter.svg"/></a>,
#  <a class="link-block-2 w-inline-block" href="https://www.instagram.com/thebridge_tech/" target="_blank"><img alt="Logo Instagram" class="rrss-image" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60a258900109553c9f25b12a_instagram.svg"/></a>,
#  <a class="link-block-2 w-inline-block" href="https://www.linkedin.com/school/the-bridge-digital-talent-accelerator/" target="_blank"><img alt="Logo LinkedIn" class="rrss-image" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60a258a537d34ea6564bc47a_linkedin.svg"/></a>,
#  <a class="link-block-2 w-inline-block" href="https://www.facebook.com/thebridgedigitaltalentaccelerator" target="_blank"><img alt="Logo Facebook" class="rrss-image" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60a258b0f7a950106811cee7_facebook.svg"/></a>,
#  <a class="link-block-2 w-inline-block" href="https://www.tiktok.com/@thebridge.tech" target="_blank"><img alt="Icono Tik Tok" class="rrss-image" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6184ed6f637104f1d02d81f0_tiktok.png"/></a>,
#  <a class="link-block-2 w-inline-block" href="https://www.youtube.com/channel/UCHOB3w7UKqaQ9FKMwI0720Q" target="_blank"><img alt="Logo youtube (blanco)" class="rrss-image" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/60fe6994cfa19341695e746a_youtube.svg"/></a>,
#  <a class="link-white" href="/aviso-legal">Aviso Legal</a>,
#  <a class="link-white" href="/politica-cookies">Política de cookies</a>,
#  <a class="link-white" href="/politica-privacidad">Política de privacidad</a>,
#  <a class="link-white" href="tel:+34919017257">Atención telefónica</a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
# Out:
# <a class="brand-2 w-nav-brand" href="/"><img alt="Logo The Bridge" class="image-2" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/607eeb4b0517b6659206c10f_thebridgelogo.svg"/></a>
# <a class="link" href="/bootcamp/online">Bootcamps ONLINE</a>
# <a class="link" href="/bootcamp/bootcamps-full-time">Bootcamps Full Time</a>
# <a class="link" href="/bootcamp/bootcamps-part-time">Bootcamps part Time</a>
# <a class="link-header link-header-hover" href="/bootcamps/bootcamp-ciberseguridad">Ciberseguridad</a>

# %% [markdown]
# ## Obtener los títulos del ¿Qué aprenderas? (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un libro y elegimos inspeccionar)

# %%
var_1 = soup.find("h3", class_="heading-11")

# %%
print(var_1)
# Out:
# <h3 class="heading-11">Python para Data Science</h3>

# %%
all_h3 = soup.find_all("h3", class_="heading-11")
for h3 in all_h3:
    print(h3.get_text(strip=True))
# Out:
# Python para Data Science
# Data Analysis
# Machine Learning Engineering
# Productización y Negocio

# %% [markdown]
# ## Obtener los nombres, imágenes y links del linkedin de los profesores (find_all + get_text)

# %%
profes = soup.find_all("div", class_="fs-slide-content")
for profe in profes:
    print(profe)
# Out:
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/613a358c0aa9a0d0d27d11f3_miguel-angel.jpg"/><div class="fs-text">Miguel Angel Nievas</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/miguelangelnievasfuertes/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="(max-width: 479px) 100vw, 190px" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero-p-800.png 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero.png 900w"/><div class="fs-text">Alberto Romero</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/albertoromv/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="(max-width: 479px) 100vw, 190px" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto-p-800.png 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto-p-1080.png 1080w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto.png 1100w"/><div class="fs-text">Alberto Becerra</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/alberto-becerra-tome-data-science-instructor/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="(max-width: 479px) 100vw, 190px" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon-p-800.png 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon-p-1080.png 1080w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon.png 1100w"/><div class="fs-text">José Luis Gómez</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/jlgortega/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/60e584a4da592ca831acd878_MARCO%20RUSSO_LI%20DS.png"/><div class="fs-text">Marco Russo</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/marcusrb/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="(max-width: 479px) 100vw, 190px" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1).jpg" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1)-p-800.jpeg 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1)-p-1080.jpeg 1080w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1).jpg 1462w"/><div class="fs-text">Gustavo Martín</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/gustavomartinvela/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="(max-width: 479px) 100vw, 190px" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco.jpeg" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco-p-500.jpeg 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco.jpeg 718w"/><div class="fs-text">Fernando Carrasco</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/fernando-carrasco-847a28aa/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/63357b80e8f05d18fa0738cb_Copia%20de%20foto.jpeg"/><div class="fs-text">Carlos Sevilla</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/carlos-sevilla-barcel%C3%B3/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="(max-width: 479px) 100vw, 190px" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle.png 640w"/><div class="fs-text">Miguel Ángel Valle</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/mvalleheath/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/613a358c0aa9a0d0d27d11f3_miguel-angel.jpg"/><div class="fs-text">Miguel Angel Nievas</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/miguelangelnievasfuertes/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="100vw" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero-p-800.png 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero.png 900w"/><div class="fs-text">Alberto Romero</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/albertoromv/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="100vw" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto-p-800.png 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto-p-1080.png 1080w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto.png 1100w"/><div class="fs-text">Alberto Becerra</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/alberto-becerra-tome-data-science-instructor/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="100vw" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon-p-800.png 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon-p-1080.png 1080w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon.png 1100w"/><div class="fs-text">José Luis Gómez</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/jlgortega/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/60e584a4da592ca831acd878_MARCO%20RUSSO_LI%20DS.png"/><div class="fs-text">Marco Russo</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/marcusrb/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="100vw" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1).jpg" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1)-p-800.jpeg 800w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1)-p-1080.jpeg 1080w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1).jpg 1462w"/><div class="fs-text">Gustavo Martín</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/gustavomartinvela/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="100vw" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco.jpeg" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco-p-500.jpeg 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco.jpeg 718w"/><div class="fs-text">Fernando Carrasco</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/fernando-carrasco-847a28aa/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/63357b80e8f05d18fa0738cb_Copia%20de%20foto.jpeg"/><div class="fs-text">Carlos Sevilla</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/carlos-sevilla-barcel%C3%B3/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>
# <div class="fs-slide-content"><img alt="" class="fs-image" loading="lazy" sizes="100vw" src="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle.png" srcset="https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle-p-500.png 500w, https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle.png 640w"/><div class="fs-text">Miguel Ángel Valle</div><div class="fs-job">Lead Instructor</div><a class="fs-link w-inline-block" href="https://www.linkedin.com/in/mvalleheath/" target="_blank"><img alt="Icono LinkedIn" loading="lazy" src="https://uploads-ssl.webflow.com/60780bff57ddc42a6adc1d7e/6364fb56b7651575416e2738_icono-linkedin.png" width="40"/></a></div>

# %%
profes = soup.find_all("div", class_="fs-text")
for profe in profes:
    print(profe)
# Out:
# <div class="fs-text">Miguel Angel Nievas</div>
# <div class="fs-text">Alberto Romero</div>
# <div class="fs-text">Alberto Becerra</div>
# <div class="fs-text">José Luis Gómez</div>
# <div class="fs-text">Marco Russo</div>
# <div class="fs-text">Gustavo Martín</div>
# <div class="fs-text">Fernando Carrasco</div>
# <div class="fs-text">Carlos Sevilla</div>
# <div class="fs-text">Miguel Ángel Valle</div>
# <div class="fs-text">Miguel Angel Nievas</div>
# <div class="fs-text">Alberto Romero</div>
# <div class="fs-text">Alberto Becerra</div>
# <div class="fs-text">José Luis Gómez</div>
# <div class="fs-text">Marco Russo</div>
# <div class="fs-text">Gustavo Martín</div>
# <div class="fs-text">Fernando Carrasco</div>
# <div class="fs-text">Carlos Sevilla</div>
# <div class="fs-text">Miguel Ángel Valle</div>

# %%
profes = soup.find_all("div", class_="fs-slide-content")
for profe in profes:
    print(profe.find('img').get('src'))
# Out:
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/613a358c0aa9a0d0d27d11f3_miguel-angel.jpg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/60e584a4da592ca831acd878_MARCO%20RUSSO_LI%20DS.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1).jpg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco.jpeg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/63357b80e8f05d18fa0738cb_Copia%20de%20foto.jpeg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/613a358c0aa9a0d0d27d11f3_miguel-angel.jpg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/62d52849074c2e7609477546_Alberto_Romero.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/639b3feca5ce5fd3c24d967d_Foto-alberto.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/638e1295b69ba827e3dc2635_joseramon.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/60e584a4da592ca831acd878_MARCO%20RUSSO_LI%20DS.png
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/624a91a92fd62063d8fbee73_IMG_20180924_094619%20(1).jpg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/632037cb5478cc7416eecc5a_Fernando%20Carrasco.jpeg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/63357b80e8f05d18fa0738cb_Copia%20de%20foto.jpeg
# https://uploads-ssl.webflow.com/60782404b8e195845053206a/632d570b49c0b16b4a0700f9_Miguel-Angel-Valle.png

# %%
profes = soup.find_all("div", class_="fs-slide-content")
for profe in profes:
    print(profe.find('a').get('href'))
# Out:
# https://www.linkedin.com/in/miguelangelnievasfuertes/
# https://www.linkedin.com/in/albertoromv/
# https://www.linkedin.com/in/alberto-becerra-tome-data-science-instructor/
# https://www.linkedin.com/in/jlgortega/
# https://www.linkedin.com/in/marcusrb/
# https://www.linkedin.com/in/gustavomartinvela/
# https://www.linkedin.com/in/fernando-carrasco-847a28aa/
# https://www.linkedin.com/in/carlos-sevilla-barcel%C3%B3/
# https://www.linkedin.com/in/mvalleheath/
# https://www.linkedin.com/in/miguelangelnievasfuertes/
# https://www.linkedin.com/in/albertoromv/
# https://www.linkedin.com/in/alberto-becerra-tome-data-science-instructor/
# https://www.linkedin.com/in/jlgortega/
# https://www.linkedin.com/in/marcusrb/
# https://www.linkedin.com/in/gustavomartinvela/
# https://www.linkedin.com/in/fernando-carrasco-847a28aa/
# https://www.linkedin.com/in/carlos-sevilla-barcel%C3%B3/
# https://www.linkedin.com/in/mvalleheath/

# %% [markdown]
# ## Almacenar la información en un dataframe

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio almacenar en dataframe</h3>
#
#
# <ol>
#     <li>Crea un diccionario con las keys que vamos a recoger (nombre, foto, rol y link) y listas vacías</li>
#     <li>Escoge la etiqueta que vamos a buscar y recorrer. Implementa un bucle for.</li>
#     <li>Captura cada dato por profesor y almacénalo en el diccionario</li>
#     <li>Una vez finalizado, guarda ese diccionario con los valores recogidos en un dataframe</li>
#     <li>Crea un bucle para recoger la misma información del claustro de las diferentes verticales de la escuela</li>
# </ol>
#
#  </td></tr>
# </table>
