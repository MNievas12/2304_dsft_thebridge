# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

chipo = pd.read_csv(url, sep='\t')

chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo = pd.read_table(url)
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
chipo['item_price'].max()
# Out:
# '$9.39 '

# %%
chipo['item_price'] = chipo['item_price'].str.replace("$","")
# Out:
# c:\Users\Miguel Angel\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
# chipo['item_price'] = chipo['item_price'].str[1:]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
chipo['item_price'] = chipo['item_price'].astype(float)

# %%
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
chipo['item_price'].max()
# Out:
# 44.25

# %%
chipo[chipo['item_price'] == chipo['item_price'].max()]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
chipo['unit_price'] = chipo['item_price'] / chipo['quantity']
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %%
chipo[chipo['unit_price'] == chipo['unit_price'].max()]
# Out:
#       order_id  quantity            item_name  \
# 281        123         2     Steak Salad Bowl
# 606        250         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 2442       970         1  Barbacoa Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 2740      1088         1     Steak Salad Bowl
# 2804      1114         1     Steak Salad Bowl
# ...

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price  unit_price
# 0                                                NaN        2.39        2.39
# 1                                       [Clementine]        3.39        3.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo[chipo['unit_price'] > 10]['item_name'].nunique()
# Out:
# 25

# %% [markdown]
# ### 4.1: Cuántos pedidos se han hecho con un producto de más de 10$? Es lo mismo?

# %%
chipo[chipo['unit_price'] > 10]['order_id'].nunique()
# Out:
# 787

# %%
productos_10 = chipo[chipo['unit_price'] > 10]['item_name'].unique()
productos_10
# Out:
# array(['Chicken Bowl', 'Steak Burrito', 'Chicken Burrito',
#        'Barbacoa Bowl', 'Veggie Burrito', 'Veggie Bowl',
#        'Chicken Soft Tacos', 'Steak Bowl', 'Carnitas Burrito',
#        'Carnitas Bowl', 'Barbacoa Burrito', 'Chicken Salad Bowl',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl', 'Chicken Salad',
#        'Steak Salad Bowl', 'Chicken Crispy Tacos', 'Veggie Soft Tacos',
#        'Barbacoa Soft Tacos', 'Carnitas Crispy Tacos',
#        'Carnitas Salad Bowl', 'Barbacoa Salad Bowl', 'Steak Soft Tacos',
#        'Carnitas Soft Tacos', 'Steak Crispy Tacos'], dtype=object)

# %%
len(chipo[chipo['item_name'].isin(productos_10)]['order_id'].unique()) # incorrecto
# Out:
# 1826

# %%
chipo[chipo['item_name']=="Steak Soft Tacos"]
# Out:
#       order_id  quantity         item_name  \
# 8            4         1  Steak Soft Tacos
# 61          28         1  Steak Soft Tacos
# 65          29         1  Steak Soft Tacos
# 84          37         1  Steak Soft Tacos
# 118         52         1  Steak Soft Tacos
# 175         78         1  Steak Soft Tacos
# 184         83         1  Steak Soft Tacos
# 266        116         1  Steak Soft Tacos
# 278        122         1  Steak Soft Tacos
# 293        128         1  Steak Soft Tacos
# 299        130         1  Steak Soft Tacos
# 342        149         1  Steak Soft Tacos
# 390        169         1  Steak Soft Tacos
# 494        207         1  Steak Soft Tacos
# 570        234         1  Steak Soft Tacos
# 961        395         1  Steak Soft Tacos
# 968        397         1  Steak Soft Tacos
# 1353       552         1  Steak Soft Tacos
# 1365       558         1  Steak Soft Tacos
# 1542       627         1  Steak Soft Tacos
# 1617       653         1  Steak Soft Tacos
# ...

# %%
chipo.groupby("item_name")['unit_price'].mean()
# Out:
# item_name
# 6 Pack Soft Drink                         6.490000
# Barbacoa Bowl                            10.187273
# Barbacoa Burrito                          9.832418
# Barbacoa Crispy Tacos                    10.087273
# Barbacoa Salad Bowl                      10.640000
# Barbacoa Soft Tacos                      10.018400
# Bottled Water                             1.431667
# Bowl                                      7.400000
# Burrito                                   7.400000
# Canned Soda                               1.090000
# Canned Soft Drink                         1.250000
# Carnitas Bowl                            10.315588
# Carnitas Burrito                          9.975932
# Carnitas Crispy Tacos                     9.852857
# Carnitas Salad                            8.990000
# Carnitas Salad Bowl                      11.056667
# Carnitas Soft Tacos                       9.398500
# Chicken Bowl                              9.657727
# ...

# %%
chipo.iloc[4619]
# Out:
# order_id                                                           1834
# quantity                                                              1
# item_name                                            Chicken Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# item_price                                                        11.25
# unit_price                                                        11.25
# Name: 4619, dtype: object

# %% [markdown]
# ### Step 5. What is the price of each item and name it unit_price. Get only item_name and unit_price

# %%
chipo[['item_name',"unit_price"]].drop_duplicates().head(30)
# Out:
#                                 item_name  unit_price
# 0            Chips and Fresh Tomato Salsa        2.39
# 1                                    Izze        3.39
# 2                        Nantucket Nectar        3.39
# 3   Chips and Tomatillo-Green Chili Salsa        2.39
# 4                            Chicken Bowl        8.49
# 5                            Chicken Bowl       10.98
# 6                           Side of Chips        1.69
# 7                           Steak Burrito       11.75
# 8                        Steak Soft Tacos        9.25
# 9                           Steak Burrito        9.25
# 10                    Chips and Guacamole        4.45
# 11                   Chicken Crispy Tacos        8.75
# 12                     Chicken Soft Tacos        8.75
# 13                           Chicken Bowl       11.25
# 16                        Chicken Burrito        8.49
# 18                            Canned Soda        1.09
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(['item_name'], ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
chipo[chipo['unit_price'] == chipo['unit_price'].max()]['quantity'].sum()
# Out:
# 30

# %%
chipo['item_price'].idxmax()
# Out:
# 3598

# %%
chipo.loc[chipo['item_price'].idxmax(), 'quantity']
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
len(chipo[chipo['item_name'] == "Veggie Salad Bowl"])
# Out:
# 18

# %%
chipo['item_name'].value_counts()['Veggie Salad Bowl']
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
len(chipo[(chipo['item_name'] == "Canned Soda") & (chipo['quantity'] > 1)])
# Out:
# 20

# %%
chipo[(chipo['item_name'] == "Canned Soda") & (chipo['quantity'] > 1)]['order_id'].nunique()
# Out:
# 18
