# %% [markdown]
# # Ejercicio análisis time series
# Para este ejercicio vas a trabajar con el histórico de valores en bolsa de una empresa que se dedica a vender muebles. Se pide
# 1. Importa los datos 'df_furniture.csv'
# 2. Trata la fecha como texto. Crea una columna para el año, mes y dia, y a partir de esas columnas crea la de fecha, en formato datetime de pandas
# 3. ¿De qué fecha a qué fecha va el histórico?
# 4. ¿Cómo es la serie temporal? ¿Tiene tendencia? ¿Aprecias alguna estacionalidad?
# 5. ¿Podrías demostrar de dos maneras estadísticas que la serie no es stationary?
# 6. Parece que hay una tendencia, pero no se aprecia bien con tanto pico en la serie. ¿Conoces algún método para representar mejor la tendencia?
# 7. Estaría bien visualizar todos los componentes de la serie temporal por separado
# 8. Demuestra mediante una gráfica de autocorrelación que la serie es estacional
# 9. ¿Qué dependencia tiene cada instante de sus ultimos 5 lags? Demuéstralo mediante una matriz de correlación. ¿Esto es bueno para los modelos?
# 10. Ya hemos visto que hay seasonality. ¿Cada cuántos instantes se cumple ese patrón?
# 11. Para un futuro modelado de los datos necesitaremos eliminar la tendencia. ¿Cómo hacemos esto?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Cargamos los datos

# %%
df = pd.read_csv('data/df_furniture.csv')
df.head()
# Out:
#         Month  furniture_price_adjusted
# 0  1992-01-01               2073.432724
# 1  1992-02-01               2114.485812
# 2  1992-03-01               2260.570891
# 3  1992-04-01               2255.103236
# 4  1992-05-01               2331.414618

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     326 non-null    object
#  1   furniture_price_adjusted  331 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.3+ KB

# %%
df.describe()
# Out:
#        furniture_price_adjusted
# count                331.000000
# mean                5975.765787
# std                 2092.867819
# min                 2073.432724
# 25%                 4280.088499
# 50%                 6075.405272
# 75%                 7381.403461
# max                10833.501852

# %% [markdown]
# ## 2. Tratar la fecha como texto y parsear

# %%
df[df['Month'].isna()]
# Out:
#    Month  furniture_price_adjusted
# 15   NaN               2457.704334
# 21   NaN               2715.938414
# 39   NaN               2857.008678
# 40   NaN               3086.648631
# 60   NaN               3298.628987

# %%
df['Month'] = pd.to_datetime(df['Month'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     326 non-null    datetime64[ns]
#  1   furniture_price_adjusted  331 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.3 KB

# %% [markdown]
# ## 3. ¿De qué fecha a qué fecha va el histórico?

# %%
df['Month'].min()
# Out:
# Timestamp('1992-01-01 00:00:00')

# %%
df['Month'].max()
# Out:
# Timestamp('2019-07-01 00:00:00')

# %%
fechas = pd.date_range(df['Month'].min(), df['Month'].max(), freq='MS')
fechas
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01',
#                '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01',
#                '2019-06-01', '2019-07-01'],
#               dtype='datetime64[ns]', length=331, freq='MS')

# %%
fechas.freq

# %%
df['Month'] = fechas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     331 non-null    datetime64[ns]
#  1   furniture_price_adjusted  331 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.3 KB

# %%
df.set_index('Month', inplace=True)
df.head()
# Out:
#             furniture_price_adjusted
# Month
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618

# %% [markdown]
# ## 4. ¿Cómo es la serie temporal? ¿Tiene tendencia? ¿Aprecias alguna estacionalidad?

# %%
plt.figure(figsize=(20,10))
plt.plot(df)

# %% [markdown]
# ## 5. ¿Podrías demostrar de dos maneras estadísticas que la serie no es stationary?

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['furniture_price_adjusted'])
result[1]
# Out:
# 0.7035529748089981

# %%
result
# Out:
# (-1.1285507258736949,
#  0.7035529748089981,
#  14,
#  316,
#  {'1%': -3.4512146067362317,
#   '5%': -2.870730188960711,
#   '10%': -2.5716664849383113},
#  4197.675275795754)

# %%
if result[1] < 0.05:
    print("Rechazo h. nula, por lo tanto es estacionaria")
else: 
    print("Acepto h. nula, por lo tanto no es estacionaria")
# Out:
# Acepto h. nula, por lo tanto no es estacionaria

# %%
int(len(df)/2)
# Out:
# 165

# %%
df[:int(len(df)/2)].describe()
# Out:
#        furniture_price_adjusted
# count                165.000000
# mean                4366.695881
# std                 1412.738867
# min                 2073.432724
# 25%                 3115.400080
# 50%                 4275.168742
# 75%                 5428.334524
# max                 8110.153770

# %%
df[int(len(df)/2):].describe()
# Out:
#        furniture_price_adjusted
# count                166.000000
# mean                7575.142501
# std                 1270.370560
# min                 5349.481724
# 25%                 6613.056182
# 50%                 7345.578004
# 75%                 8439.580036
# max                10833.501852

# %% [markdown]
# ## 6. ¿Conoces algún método para representar mejor la tendencia?

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result_add = seasonal_decompose(df['furniture_price_adjusted'], model='additive', extrapolate_trend='freq')

# %%
plt.figure(figsize=(15,10))

plt.plot(result_add.trend)

# %%
df_ma = df['furniture_price_adjusted'].rolling(3).mean()

plt.figure(figsize=(15,10))

plt.plot(df_ma)

# %% [markdown]
# ## 7. Estaría bien visualizar todos los componentes de la serie temporal por separado

# %%
# plt.figure(figsize=(15,10))
result_add.plot();

# %% [markdown]
# ## 8. Demuestra mediante una gráfica de autocorrelación que la serie es estacional

# %%
from pandas.plotting import autocorrelation_plot

plt.figure(figsize=(15,10))
autocorrelation_plot(df['furniture_price_adjusted']);

# %% [markdown]
# ## 9. ¿Qué dependencia tiene cada instante de sus últimos 5 lags? Demuéstralo mediante una matriz de correlación.

# %%
df.corr()
# Out:
#                           furniture_price_adjusted
# furniture_price_adjusted                       1.0

# %%
for i in range(5,0,-1):
    df['t-'+str(i)] = df['furniture_price_adjusted'].shift(i)

df
# Out:
#             furniture_price_adjusted           t-5           t-4  \
# Month
# 1992-01-01               2073.432724           NaN           NaN
# 1992-02-01               2114.485812           NaN           NaN
# 1992-03-01               2260.570891           NaN           NaN
# 1992-04-01               2255.103236           NaN           NaN
# 1992-05-01               2331.414618           NaN   2073.432724
# ...                              ...           ...           ...
# 2019-03-01               9718.107698   9569.037851  10380.194097
# 2019-04-01               9248.814254  10380.194097  10726.595075
# 2019-05-01              10001.305304  10726.595075   8431.965334
# 2019-06-01               9431.337229   8431.965334   8271.237355
# 2019-07-01               9887.800688   8271.237355   9718.107698
#
#                      t-3           t-2           t-1
# Month
# 1992-01-01           NaN           NaN           NaN
# 1992-02-01           NaN           NaN   2073.432724
# 1992-03-01           NaN   2073.432724   2114.485812
# 1992-04-01   2073.432724   2114.485812   2260.570891
# 1992-05-01   2114.485812   2260.570891   2255.103236
# ...                  ...           ...           ...
# 2019-03-01  10726.595075   8431.965334   8271.237355
# 2019-04-01   8431.965334   8271.237355   9718.107698
# 2019-05-01   8271.237355   9718.107698   9248.814254
# 2019-06-01   9718.107698   9248.814254  10001.305304
# 2019-07-01   9248.814254  10001.305304   9431.337229
#
# [331 rows x 6 columns]

# %%
df.dropna(inplace=True)
df.head()
# Out:
#             furniture_price_adjusted          t-5          t-4          t-3  \
# Month
# 1992-06-01               2384.638567  2073.432724  2114.485812  2260.570891
# 1992-07-01               2417.165376  2114.485812  2260.570891  2255.103236
# 1992-08-01               2445.498729  2260.570891  2255.103236  2331.414618
# 1992-09-01               2387.351705  2255.103236  2331.414618  2384.638567
# 1992-10-01               2489.350838  2331.414618  2384.638567  2417.165376
#
#                     t-2          t-1
# Month
# 1992-06-01  2255.103236  2331.414618
# 1992-07-01  2331.414618  2384.638567
# 1992-08-01  2384.638567  2417.165376
# 1992-09-01  2417.165376  2445.498729
# 1992-10-01  2445.498729  2387.351705

# %%
plt.figure(figsize=(15,10))

sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 10. Ya hemos visto que hay seasonality. ¿Cada cuántos instantes se cumple ese patrón?

# %% [markdown]
# Cada 12 meses como hemos comprobado en apartados anteriores

# %% [markdown]
# ## 11. Para un futuro modelado de los datos necesitaremos eliminar la tendencia. ¿Cómo hacemos esto?

# %%
result_add.trend
# Out:
# Month
# 1992-01-01    2281.273741
# 1992-02-01    2299.125517
# 1992-03-01    2316.977292
# 1992-04-01    2334.829068
# 1992-05-01    2352.680844
#                  ...
# 2019-03-01    9617.009691
# 2019-04-01    9629.636014
# 2019-05-01    9642.262337
# 2019-06-01    9654.888660
# 2019-07-01    9667.514983
# Name: trend, Length: 331, dtype: float64

# %%
df['detrend_values'] = df['furniture_price_adjusted'] - result_add.trend
plt.plot(df['detrend_values'])
